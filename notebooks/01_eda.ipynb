# %% [markdown]
# # Bemorga dori tavsiya qilish tizimi

# %% [markdown]
# Decision Tree algorthmi yordamida bemorlarni guruhlarga ajratamiz.

# %% [markdown]
# Kerakli kutubxonalarni chaqirib olamiz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/drug200.csv")
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %% [markdown]
# Ustunlar:
# - `Age` - yosh
# - `Sex` - jins
# - `BP` - qon bosimi
# - `Cholesterol` - qondagi xolesterol
# - `Na_to_K` - organizmdagi natriy miqdorining kaliyga nisbati
# - `Drug` - dori turi

# %%
df.shape # Dataframening hajmini ko'ramiz
# Out:
# (200, 6)

# %%
df.info() # Umumiy malumot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df['BP'].value_counts()
# Out:
# BP
# HIGH      77
# LOW       64
# NORMAL    59
# Name: count, dtype: int64

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# HIGH      103
# NORMAL     97
# Name: count, dtype: int64

# %%
df['Drug'].value_counts()
# Out:
# Drug
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: count, dtype: int64

# %% [markdown]
# Grafik orqali tasimot va Outlier qiymatlarni tekshiramiz

# %%
sns.histplot(data=df['Age'])
plt.show()

# %%
sns.histplot(data=df['Na_to_K'])
plt.show()

# %%
sns.boxplot(data=df['Na_to_K'])
plt.show()

# %%
sns.boxplot(data=df['Age'])
plt.show()
