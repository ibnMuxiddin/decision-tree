# %% [markdown]
# # Bemorga dori tavsiya qilish tizimi

# %% [markdown]
# Kerakli kutubxonalarni chaqirib olamiz

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split # Datasetni train va test setlarga ajratish
from sklearn.ensemble import RandomForestClassifier # Random Forest algorthmini chaqirish
from sklearn.metrics import classification_report # Modelni baholsh
from sklearn.metrics import confusion_matrix # Modelni baholash
from matplotlib import pyplot as plt # Grafiklar
import seaborn as sns # Grafiklar
import joblib # Tayyor modelni yuklab olish
